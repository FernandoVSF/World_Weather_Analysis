# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wdescr = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_wdescr})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tuatapere
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | miri
# Processing Record 4 of Set 1 | agirish
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | margate
# Processing Record 9 of Set 1 | pevek
# Processing Record 10 of Set 1 | ostrogozhsk
# Processing Record 11 of Set 1 | padang
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | zuwarah
# Processing Record 14 of Set 1 | birao
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | ossora
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | okato
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | alvarado
# Processing Record 22 of Set 1 | hangu
# Processing Record 23 of Set 1 | kapit
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | kenai
# Processing Record 26 of Set 1 | tsabong
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | nizwa
# Processing Record 30 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | kalaswala
# Processing Record 33 of Set 1 | buchanan
# Processing Record 34 of Set 1 | springbok
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | linxi
# Processing Record 37 of Set 1 | kahului
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 1 | tutin
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | nemuro
# Processing Record 45 of Set 1 | bajil
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | bonavista
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | san patricio
# Processing Record 3 of Set 2 | hasaki
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | avera
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | grand gaube
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | ocos
# Processing Record 12 of Set 2 | pietarsaari
# Processing Record 13 of Set 2 | marica
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | sur
# Processing Record 17 of Set 2 | palmer
# Processing Record 18 of Set 2 | san quintin
# Processing Record 19 of Set 2 | biak
# Processing Record 20 of Set 2 | kisangani
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | bermejo
# Processing Record 24 of Set 2 | cardoso
# Processing Record 25 of Set 2 | richards bay
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | san-pedro
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | beja
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | port-cartier
# Processing Record 33 of Set 2 | aykhal
# Processing Record 34 of Set 2 | batagay-alyta
# Processing Record 35 of Set 2 | wencheng
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | lisala
# Processing Record 39 of Set 2 | tiksi
# Processing Record 40 of Set 2 | lethem
# Processing Record 41 of Set 2 | marawi
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | bathsheba
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | telhara
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | harper
# Processing Record 49 of Set 2 | matara
# Processing Record 50 of Set 2 | sao joao da barra
# Processing Record 1 of Set 3 | pisco
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | puerto lopez
# Processing Record 4 of Set 3 | severo-kurilsk
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | gat
# Processing Record 7 of Set 3 | foam lake
# Processing Record 8 of Set 3 | guerrero negro
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | taoudenni
# Processing Record 11 of Set 3 | belmonte
# Processing Record 12 of Set 3 | inhambane
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | tome-acu
# City not found. Skipping...
# Processing Record 15 of Set 3 | rawson
# Processing Record 16 of Set 3 | zhigansk
# Processing Record 17 of Set 3 | hami
# Processing Record 18 of Set 3 | bulawayo
# Processing Record 19 of Set 3 | shingu
# Processing Record 20 of Set 3 | fairbanks
# Processing Record 21 of Set 3 | mayma
# Processing Record 22 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 3 | bhadrachalam
# Processing Record 26 of Set 3 | vila velha
# Processing Record 27 of Set 3 | lodeynoye pole
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | chokurdakh
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | pocone
# Processing Record 32 of Set 3 | sicuani
# Processing Record 33 of Set 3 | quatre cocos
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | bara
# Processing Record 36 of Set 3 | cockburn town
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | bandarbeyla
# Processing Record 39 of Set 3 | luohe
# Processing Record 40 of Set 3 | longyan
# Processing Record 41 of Set 3 | kalmunai
# Processing Record 42 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 3 | itoman
# Processing Record 44 of Set 3 | bluff
# Processing Record 45 of Set 3 | azangaro
# Processing Record 46 of Set 3 | road town
# Processing Record 47 of Set 3 | saint anthony
# Processing Record 48 of Set 3 | kathmandu
# Processing Record 49 of Set 3 | leshan
# Processing Record 50 of Set 3 | kaseda
# Processing Record 1 of Set 4 | krasnyy chikoy
# Processing Record 2 of Set 4 | plast
# Processing Record 3 of Set 4 | butaritari
# Processing Record 4 of Set 4 | syedove
# Processing Record 5 of Set 4 | kedougou
# Processing Record 6 of Set 4 | airai
# Processing Record 7 of Set 4 | mount isa
# Processing Record 8 of Set 4 | jumla
# Processing Record 9 of Set 4 | mayo
# Processing Record 10 of Set 4 | sainte-claire
# Processing Record 11 of Set 4 | leeton
# Processing Record 12 of Set 4 | ode
# Processing Record 13 of Set 4 | ostrovnoy
# Processing Record 14 of Set 4 | grindavik
# Processing Record 15 of Set 4 | sucua
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | hithadhoo
# Processing Record 18 of Set 4 | gizo
# Processing Record 19 of Set 4 | poum
# Processing Record 20 of Set 4 | sabancuy
# Processing Record 21 of Set 4 | miraflores
# Processing Record 22 of Set 4 | puerto colombia
# Processing Record 23 of Set 4 | bilibino
# Processing Record 24 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 25 of Set 4 | ouesso
# Processing Record 26 of Set 4 | vardo
# Processing Record 27 of Set 4 | nikolskoye
# Processing Record 28 of Set 4 | stornoway
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | saint-pierre
# Processing Record 31 of Set 4 | bajo baudo
# City not found. Skipping...
# Processing Record 32 of Set 4 | cordoba
# Processing Record 33 of Set 4 | yamada
# Processing Record 34 of Set 4 | port elizabeth
# Processing Record 35 of Set 4 | yar-sale
# Processing Record 36 of Set 4 | buala
# Processing Record 37 of Set 4 | meybod
# Processing Record 38 of Set 4 | yabassi
# Processing Record 39 of Set 4 | nsanje
# Processing Record 40 of Set 4 | bambous virieux
# Processing Record 41 of Set 4 | puerto ayora
# Processing Record 42 of Set 4 | campbell river
# Processing Record 43 of Set 4 | olga
# Processing Record 44 of Set 4 | tuensang
# Processing Record 45 of Set 4 | forotic
# Processing Record 46 of Set 4 | tezu
# Processing Record 47 of Set 4 | port hardy
# Processing Record 48 of Set 4 | pindushi
# Processing Record 49 of Set 4 | egvekinot
# Processing Record 50 of Set 4 | aklavik
# Processing Record 1 of Set 5 | hilo
# Processing Record 2 of Set 5 | esperance
# Processing Record 3 of Set 5 | isangel
# Processing Record 4 of Set 5 | sosenskiy
# Processing Record 5 of Set 5 | hualmay
# Processing Record 6 of Set 5 | atasu
# Processing Record 7 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 5 | siauliai
# Processing Record 9 of Set 5 | kawhia
# Processing Record 10 of Set 5 | uvalde
# Processing Record 11 of Set 5 | culpeper
# Processing Record 12 of Set 5 | kerema
# Processing Record 13 of Set 5 | olavarria
# Processing Record 14 of Set 5 | karpogory
# Processing Record 15 of Set 5 | sumbe
# Processing Record 16 of Set 5 | vila franca do campo
# Processing Record 17 of Set 5 | shenjiamen
# Processing Record 18 of Set 5 | basco
# Processing Record 19 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 20 of Set 5 | yumaguzino
# Processing Record 21 of Set 5 | ardakan
# Processing Record 22 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 5 | shintomi
# Processing Record 24 of Set 5 | naze
# Processing Record 25 of Set 5 | ekibastuz
# Processing Record 26 of Set 5 | sao luiz gonzaga
# Processing Record 27 of Set 5 | les cayes
# Processing Record 28 of Set 5 | lindas
# Processing Record 29 of Set 5 | arman
# Processing Record 30 of Set 5 | tura
# Processing Record 31 of Set 5 | kruisfontein
# Processing Record 32 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 5 | ovalle
# Processing Record 34 of Set 5 | kamenka
# Processing Record 35 of Set 5 | namatanai
# Processing Record 36 of Set 5 | vaitape
# Processing Record 37 of Set 5 | methoni
# Processing Record 38 of Set 5 | port lincoln
# Processing Record 39 of Set 5 | san ramon de la nueva oran
# Processing Record 40 of Set 5 | castro
# Processing Record 41 of Set 5 | tateyama
# Processing Record 42 of Set 5 | mao
# Processing Record 43 of Set 5 | millet
# Processing Record 44 of Set 5 | mount gambier
# Processing Record 45 of Set 5 | mitsamiouli
# Processing Record 46 of Set 5 | salisbury
# Processing Record 47 of Set 5 | antofagasta
# Processing Record 48 of Set 5 | lompoc
# Processing Record 49 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 5 | turayf
# Processing Record 1 of Set 6 | chuy
# Processing Record 2 of Set 6 | dharchula
# Processing Record 3 of Set 6 | aloleng
# Processing Record 4 of Set 6 | along
# Processing Record 5 of Set 6 | ihosy
# Processing Record 6 of Set 6 | half moon bay
# Processing Record 7 of Set 6 | mari-turek
# Processing Record 8 of Set 6 | chumikan
# Processing Record 9 of Set 6 | tambopata
# Processing Record 10 of Set 6 | sakakah
# Processing Record 11 of Set 6 | mareeba
# Processing Record 12 of Set 6 | hambantota
# Processing Record 13 of Set 6 | konigs wusterhausen
# Processing Record 14 of Set 6 | nanortalik
# Processing Record 15 of Set 6 | alofi
# Processing Record 16 of Set 6 | matagami
# Processing Record 17 of Set 6 | naryan-mar
# Processing Record 18 of Set 6 | iqaluit
# Processing Record 19 of Set 6 | provideniya
# Processing Record 20 of Set 6 | barcelos
# Processing Record 21 of Set 6 | castellammare del golfo
# Processing Record 22 of Set 6 | karlskrona
# Processing Record 23 of Set 6 | beaverlodge
# Processing Record 24 of Set 6 | olafsvik
# Processing Record 25 of Set 6 | havre-saint-pierre
# Processing Record 26 of Set 6 | buraydah
# Processing Record 27 of Set 6 | ucluelet
# Processing Record 28 of Set 6 | kristiansund
# Processing Record 29 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 6 | pitimbu
# Processing Record 31 of Set 6 | pout
# Processing Record 32 of Set 6 | maarianhamina
# Processing Record 33 of Set 6 | srednekolymsk
# Processing Record 34 of Set 6 | merauke
# Processing Record 35 of Set 6 | luderitz
# Processing Record 36 of Set 6 | ngunguru
# Processing Record 37 of Set 6 | iskateley
# Processing Record 38 of Set 6 | sitka
# Processing Record 39 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 6 | sola
# Processing Record 42 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 6 | fernie
# Processing Record 44 of Set 6 | namibe
# Processing Record 45 of Set 6 | norman wells
# Processing Record 46 of Set 6 | fort nelson
# Processing Record 47 of Set 6 | sinnamary
# Processing Record 48 of Set 6 | hargeysa
# Processing Record 49 of Set 6 | sao filipe
# Processing Record 50 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 7 | bud
# Processing Record 2 of Set 7 | jamame
# Processing Record 3 of Set 7 | tayu
# Processing Record 4 of Set 7 | vao
# Processing Record 5 of Set 7 | zaragoza
# Processing Record 6 of Set 7 | estepona
# Processing Record 7 of Set 7 | shirokiy
# Processing Record 8 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 7 | virginia beach
# Processing Record 10 of Set 7 | kavieng
# Processing Record 11 of Set 7 | zatoka
# Processing Record 12 of Set 7 | lagoa
# Processing Record 13 of Set 7 | kuusamo
# Processing Record 14 of Set 7 | tulun
# Processing Record 15 of Set 7 | pangnirtung
# Processing Record 16 of Set 7 | karasjok
# Processing Record 17 of Set 7 | udachnyy
# Processing Record 18 of Set 7 | port blair
# Processing Record 19 of Set 7 | sioux lookout
# Processing Record 20 of Set 7 | krasnoborsk
# Processing Record 21 of Set 7 | trincomalee
# Processing Record 22 of Set 7 | swan hill
# Processing Record 23 of Set 7 | paracuru
# Processing Record 24 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 7 | algiers
# Processing Record 26 of Set 7 | yulara
# Processing Record 27 of Set 7 | xining
# Processing Record 28 of Set 7 | mizdah
# Processing Record 29 of Set 7 | jaen
# Processing Record 30 of Set 7 | lunglei
# Processing Record 31 of Set 7 | inyonga
# Processing Record 32 of Set 7 | pangody
# Processing Record 33 of Set 7 | faya
# Processing Record 34 of Set 7 | sawakin
# Processing Record 35 of Set 7 | cuiluan
# Processing Record 36 of Set 7 | aquiraz
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | tortoli
# Processing Record 39 of Set 7 | coquimbo
# Processing Record 40 of Set 7 | tambura
# Processing Record 41 of Set 7 | laguna
# Processing Record 42 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 7 | ancud
# Processing Record 44 of Set 7 | dikson
# Processing Record 45 of Set 7 | salvador
# Processing Record 46 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 7 | beira
# Processing Record 48 of Set 7 | oussouye
# Processing Record 49 of Set 7 | kupang
# Processing Record 50 of Set 7 | mae sai
# Processing Record 1 of Set 8 | bayan
# Processing Record 2 of Set 8 | angoche
# Processing Record 3 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 8 | krasnoselkup
# Processing Record 5 of Set 8 | revelstoke
# Processing Record 6 of Set 8 | henties bay
# Processing Record 7 of Set 8 | rio grande
# Processing Record 8 of Set 8 | lasa
# Processing Record 9 of Set 8 | bocas del toro
# Processing Record 10 of Set 8 | rio gallegos
# Processing Record 11 of Set 8 | ambam
# Processing Record 12 of Set 8 | leningradskiy
# Processing Record 13 of Set 8 | yabrud
# Processing Record 14 of Set 8 | brae
# Processing Record 15 of Set 8 | talnakh
# Processing Record 16 of Set 8 | ahipara
# Processing Record 17 of Set 8 | flinders
# Processing Record 18 of Set 8 | kununurra
# Processing Record 19 of Set 8 | harigue
# City not found. Skipping...
# Processing Record 20 of Set 8 | dalbandin
# Processing Record 21 of Set 8 | akyab
# Processing Record 22 of Set 8 | santa cruz cabralia
# Processing Record 23 of Set 8 | garowe
# Processing Record 24 of Set 8 | carnarvon
# Processing Record 25 of Set 8 | kalengwa
# Processing Record 26 of Set 8 | aneho
# Processing Record 27 of Set 8 | manado
# Processing Record 28 of Set 8 | masvingo
# Processing Record 29 of Set 8 | hinton
# Processing Record 30 of Set 8 | krasne
# Processing Record 31 of Set 8 | bouna
# Processing Record 32 of Set 8 | la primavera
# Processing Record 33 of Set 8 | mamallapuram
# Processing Record 34 of Set 8 | iracoubo
# Processing Record 35 of Set 8 | haines junction
# Processing Record 36 of Set 8 | vagur
# Processing Record 37 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 8 | dehloran
# Processing Record 39 of Set 8 | mbaiki
# Processing Record 40 of Set 8 | gazojak
# Processing Record 41 of Set 8 | kendari
# Processing Record 42 of Set 8 | saint-francois
# Processing Record 43 of Set 8 | the pas
# Processing Record 44 of Set 8 | waipawa
# Processing Record 45 of Set 8 | dimbokro
# Processing Record 46 of Set 8 | birin
# Processing Record 47 of Set 8 | porto novo
# Processing Record 48 of Set 8 | farafangana
# Processing Record 49 of Set 8 | ponta delgada
# Processing Record 50 of Set 8 | caravelas
# Processing Record 1 of Set 9 | juneau
# Processing Record 2 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 4 of Set 9 | quartucciu
# Processing Record 5 of Set 9 | quelimane
# Processing Record 6 of Set 9 | leopold
# Processing Record 7 of Set 9 | ust-nera
# Processing Record 8 of Set 9 | bilma
# Processing Record 9 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 9 | bethanien
# Processing Record 11 of Set 9 | coihaique
# Processing Record 12 of Set 9 | tiznit
# Processing Record 13 of Set 9 | abu samrah
# Processing Record 14 of Set 9 | nuuk
# Processing Record 15 of Set 9 | halol
# Processing Record 16 of Set 9 | keetmanshoop
# Processing Record 17 of Set 9 | prattville
# Processing Record 18 of Set 9 | skowhegan
# Processing Record 19 of Set 9 | marystown
# Processing Record 20 of Set 9 | huarmey
# Processing Record 21 of Set 9 | verkh-usugli
# Processing Record 22 of Set 9 | jiujiang
# Processing Record 23 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 9 | la ermita
# Processing Record 25 of Set 9 | geraldton
# Processing Record 26 of Set 9 | xiantao
# Processing Record 27 of Set 9 | fortuna
# Processing Record 28 of Set 9 | bintulu
# Processing Record 29 of Set 9 | palana
# Processing Record 30 of Set 9 | vysokogornyy
# Processing Record 31 of Set 9 | faanui
# Processing Record 32 of Set 9 | high level
# Processing Record 33 of Set 9 | dingle
# Processing Record 34 of Set 9 | abaete
# Processing Record 35 of Set 9 | strezhevoy
# Processing Record 36 of Set 9 | tazovskiy
# Processing Record 37 of Set 9 | port hueneme
# Processing Record 38 of Set 9 | istisu
# Processing Record 39 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 9 | saint-gaudens
# Processing Record 41 of Set 9 | alta floresta
# Processing Record 42 of Set 9 | katsuura
# Processing Record 43 of Set 9 | stony plain
# Processing Record 44 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 9 | kieta
# Processing Record 48 of Set 9 | wau
# Processing Record 49 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 50 of Set 9 | bonthe
# Processing Record 1 of Set 10 | kefalos
# Processing Record 2 of Set 10 | arjawinangun
# Processing Record 3 of Set 10 | adrar
# Processing Record 4 of Set 10 | broken hill
# Processing Record 5 of Set 10 | madimba
# Processing Record 6 of Set 10 | saint george
# Processing Record 7 of Set 10 | vestmannaeyjar
# Processing Record 8 of Set 10 | evensk
# Processing Record 9 of Set 10 | lakes entrance
# Processing Record 10 of Set 10 | vilcun
# Processing Record 11 of Set 10 | walvis bay
# Processing Record 12 of Set 10 | torbay
# Processing Record 13 of Set 10 | selty
# Processing Record 14 of Set 10 | emba
# Processing Record 15 of Set 10 | hope
# Processing Record 16 of Set 10 | deputatskiy
# Processing Record 17 of Set 10 | sistranda
# Processing Record 18 of Set 10 | ocala
# Processing Record 19 of Set 10 | sisimiut
# Processing Record 20 of Set 10 | lora del rio
# Processing Record 21 of Set 10 | khovu-aksy
# Processing Record 22 of Set 10 | tual
# Processing Record 23 of Set 10 | seinajoki
# Processing Record 24 of Set 10 | crotone
# Processing Record 25 of Set 10 | arlit
# Processing Record 26 of Set 10 | kamogawa
# Processing Record 27 of Set 10 | hailar
# Processing Record 28 of Set 10 | maragogi
# Processing Record 29 of Set 10 | ducheng
# Processing Record 30 of Set 10 | lumberton
# Processing Record 31 of Set 10 | asmar
# Processing Record 32 of Set 10 | upington
# Processing Record 33 of Set 10 | conchas
# Processing Record 34 of Set 10 | mountain home
# Processing Record 35 of Set 10 | lerwick
# Processing Record 36 of Set 10 | kayankulam
# Processing Record 37 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 38 of Set 10 | kandrian
# Processing Record 39 of Set 10 | sorrento
# Processing Record 40 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 10 | khalkhal
# Processing Record 42 of Set 10 | lugazi
# Processing Record 43 of Set 10 | trelew
# Processing Record 44 of Set 10 | cedar city
# Processing Record 45 of Set 10 | takoradi
# Processing Record 46 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 47 of Set 10 | tucuman
# Processing Record 48 of Set 10 | kadan
# Processing Record 49 of Set 10 | tsaratanana
# Processing Record 50 of Set 10 | amapa
# Processing Record 1 of Set 11 | mezhdurechensk
# Processing Record 2 of Set 11 | emerald
# Processing Record 3 of Set 11 | puerto escondido
# Processing Record 4 of Set 11 | baijiantan
# Processing Record 5 of Set 11 | atotonilco el grande
# Processing Record 6 of Set 11 | camacha
# Processing Record 7 of Set 11 | wasilla
# Processing Record 8 of Set 11 | nisia floresta
# Processing Record 9 of Set 11 | phalombe
# Processing Record 10 of Set 11 | qianjiang
# Processing Record 11 of Set 11 | fort saint james
# Processing Record 12 of Set 11 | sibiti
# Processing Record 13 of Set 11 | de aar
# Processing Record 14 of Set 11 | puerto cabezas
# Processing Record 15 of Set 11 | glendive
# Processing Record 16 of Set 11 | san felipe
# Processing Record 17 of Set 11 | meulaboh
# Processing Record 18 of Set 11 | nome
# Processing Record 19 of Set 11 | rocha
# Processing Record 20 of Set 11 | hay river
# Processing Record 21 of Set 11 | pierre
# Processing Record 22 of Set 11 | abengourou
# Processing Record 23 of Set 11 | coahuayana
# Processing Record 24 of Set 11 | kyra
# Processing Record 25 of Set 11 | calabozo
# Processing Record 26 of Set 11 | show low
# Processing Record 27 of Set 11 | garm
# City not found. Skipping...
# Processing Record 28 of Set 11 | sinjai
# Processing Record 29 of Set 11 | camacupa
# Processing Record 30 of Set 11 | uyuni
# Processing Record 31 of Set 11 | hattiesburg
# Processing Record 32 of Set 11 | marrakesh
# Processing Record 33 of Set 11 | scarborough
# Processing Record 34 of Set 11 | bowen
# Processing Record 35 of Set 11 | burica
# City not found. Skipping...
# Processing Record 36 of Set 11 | nabire
# Processing Record 37 of Set 11 | bundaberg
# Processing Record 38 of Set 11 | midland
# Processing Record 39 of Set 11 | alyangula
# Processing Record 40 of Set 11 | shinpokh
# Processing Record 41 of Set 11 | nanyang
# Processing Record 42 of Set 11 | verkhnyaya inta
# Processing Record 43 of Set 11 | ndola
# Processing Record 44 of Set 11 | jalu
# Processing Record 45 of Set 11 | salinas
# Processing Record 46 of Set 11 | cobija
# Processing Record 47 of Set 11 | necochea
# Processing Record 48 of Set 11 | chapais
# Processing Record 49 of Set 11 | progreso
# Processing Record 50 of Set 11 | da lat
# Processing Record 1 of Set 12 | singaparna
# Processing Record 2 of Set 12 | toora-khem
# Processing Record 3 of Set 12 | khani
# Processing Record 4 of Set 12 | kamaishi
# Processing Record 5 of Set 12 | libreville
# Processing Record 6 of Set 12 | husavik
# Processing Record 7 of Set 12 | terrace bay
# Processing Record 8 of Set 12 | atbasar
# Processing Record 9 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 12 | portland
# Processing Record 11 of Set 12 | hofn
# Processing Record 12 of Set 12 | narsaq
# Processing Record 13 of Set 12 | fomboni
# Processing Record 14 of Set 12 | mlonggo
# Processing Record 15 of Set 12 | mwinilunga
# Processing Record 16 of Set 12 | college
# Processing Record 17 of Set 12 | afsin
# Processing Record 18 of Set 12 | tupsan
# Processing Record 19 of Set 12 | ambon
# Processing Record 20 of Set 12 | tamana
# Processing Record 21 of Set 12 | shetpe
# Processing Record 22 of Set 12 | mujiayingzi
# Processing Record 23 of Set 12 | altay
# Processing Record 24 of Set 12 | otradnoye
# Processing Record 25 of Set 12 | itarema
# Processing Record 26 of Set 12 | martapura
# Processing Record 27 of Set 12 | healdsburg
# Processing Record 28 of Set 12 | ifakara
# Processing Record 29 of Set 12 | dubti
# Processing Record 30 of Set 12 | brenham
# Processing Record 31 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 12 | macusani
# Processing Record 33 of Set 12 | benguela
# Processing Record 34 of Set 12 | antalaha
# Processing Record 35 of Set 12 | oum hadjer
# Processing Record 36 of Set 12 | frontera
# Processing Record 37 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 12 | rauma
# Processing Record 39 of Set 12 | yian
# City not found. Skipping...
# Processing Record 40 of Set 12 | nouadhibou
# Processing Record 41 of Set 12 | vayalar
# Processing Record 42 of Set 12 | praia da vitoria
# Processing Record 43 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 44 of Set 12 | yerbogachen
# Processing Record 45 of Set 12 | hachinohe
# Processing Record 46 of Set 12 | alegrete
# Processing Record 47 of Set 12 | riberalta
# Processing Record 48 of Set 12 | gniezno
# Processing Record 49 of Set 12 | dustlik
# Processing Record 50 of Set 12 | imamoglu
# Processing Record 1 of Set 13 | araouane
# Processing Record 2 of Set 13 | srandakan
# Processing Record 3 of Set 13 | gornopravdinsk
# Processing Record 4 of Set 13 | puerto del rosario
# Processing Record 5 of Set 13 | ishigaki
# Processing Record 6 of Set 13 | kondol
# Processing Record 7 of Set 13 | mojo
# Processing Record 8 of Set 13 | marienburg
# Processing Record 9 of Set 13 | porto velho
# Processing Record 10 of Set 13 | bolshaya rechka
# Processing Record 11 of Set 13 | mandalgovi
# Processing Record 12 of Set 13 | kargasok
# Processing Record 13 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 13 | talara
# Processing Record 15 of Set 13 | maniitsoq
# Processing Record 16 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 13 | pensacola
# Processing Record 18 of Set 13 | acapulco
# Processing Record 19 of Set 13 | ye
# City not found. Skipping...
# Processing Record 20 of Set 13 | atar
# Processing Record 21 of Set 13 | mbarara
# Processing Record 22 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 13 | san luis
# Processing Record 24 of Set 13 | pacific grove
# Processing Record 25 of Set 13 | whitehorse
# Processing Record 26 of Set 13 | estevan
# Processing Record 27 of Set 13 | iquique
# Processing Record 28 of Set 13 | collie
# Processing Record 29 of Set 13 | wani
# Processing Record 30 of Set 13 | durango
# Processing Record 31 of Set 13 | kingaroy
# Processing Record 32 of Set 13 | marzuq
# Processing Record 33 of Set 13 | vostok
# Processing Record 34 of Set 13 | sao jose da coroa grande
# Processing Record 35 of Set 13 | waldshut-tiengen
# Processing Record 36 of Set 13 | tutoia
# Processing Record 37 of Set 13 | teguise
# Processing Record 38 of Set 13 | port arthur
# Processing Record 39 of Set 13 | oranjemund
# Processing Record 40 of Set 13 | zhongshu
# Processing Record 41 of Set 13 | shelburne
# Processing Record 42 of Set 13 | comodoro rivadavia
# Processing Record 43 of Set 13 | manokwari
# Processing Record 44 of Set 13 | cayenne
# Processing Record 45 of Set 13 | cerano
# Processing Record 46 of Set 13 | tall kayf
# Processing Record 47 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 13 | esfahan
# Processing Record 49 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 13 | port hawkesbury
# Processing Record 1 of Set 14 | saldanha
# Processing Record 2 of Set 14 | san carlos de bariloche
# Processing Record 3 of Set 14 | bijie
# Processing Record 4 of Set 14 | abu zabad
# Processing Record 5 of Set 14 | juba
# Processing Record 6 of Set 14 | carmen
# Processing Record 7 of Set 14 | okmulgee
# Processing Record 8 of Set 14 | labuhan
# Processing Record 9 of Set 14 | gardner
# Processing Record 10 of Set 14 | dawlatabad
# Processing Record 11 of Set 14 | catia la mar
# Processing Record 12 of Set 14 | gorontalo
# Processing Record 13 of Set 14 | dwarka
# Processing Record 14 of Set 14 | monroe
# Processing Record 15 of Set 14 | tongzhou
# Processing Record 16 of Set 14 | murovani kurylivtsi
# Processing Record 17 of Set 14 | kumla
# Processing Record 18 of Set 14 | klaeng
# Processing Record 19 of Set 14 | vuktyl
# Processing Record 20 of Set 14 | pombas
# Processing Record 21 of Set 14 | vilyuysk
# Processing Record 22 of Set 14 | andenes
# Processing Record 23 of Set 14 | gallup
# Processing Record 24 of Set 14 | bluefields
# Processing Record 25 of Set 14 | lively
# Processing Record 26 of Set 14 | thurso
# Processing Record 27 of Set 14 | bassila
# Processing Record 28 of Set 14 | svetlogorsk
# Processing Record 29 of Set 14 | maningrida
# Processing Record 30 of Set 14 | sao lourenco do oeste
# Processing Record 31 of Set 14 | valle de guadalupe
# Processing Record 32 of Set 14 | morton
# Processing Record 33 of Set 14 | medyn
# Processing Record 34 of Set 14 | algemesi
# Processing Record 35 of Set 14 | gouyave
# Processing Record 36 of Set 14 | kpandae
# Processing Record 37 of Set 14 | saint-georges
# Processing Record 38 of Set 14 | ibotirama
# Processing Record 39 of Set 14 | gidole
# Processing Record 40 of Set 14 | senno
# Processing Record 41 of Set 14 | cuenca
# Processing Record 42 of Set 14 | thohoyandou
# Processing Record 43 of Set 14 | charters towers
# Processing Record 44 of Set 14 | yatou
# Processing Record 45 of Set 14 | cidahu
# Processing Record 46 of Set 14 | yuyao
# Processing Record 47 of Set 14 | state college
# Processing Record 48 of Set 14 | vozhega
# Processing Record 49 of Set 14 | tokur
# Processing Record 50 of Set 14 | chulman
# Processing Record 1 of Set 15 | bergen
# Processing Record 2 of Set 15 | zhangye
# Processing Record 3 of Set 15 | la ronge
# Processing Record 4 of Set 15 | muisne
# Processing Record 5 of Set 15 | abeche
# Processing Record 6 of Set 15 | huallanca
# Processing Record 7 of Set 15 | luena
# Processing Record 8 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 15 | shubarkuduk
# Processing Record 10 of Set 15 | gubkinskiy
# Processing Record 11 of Set 15 | harboore
# Processing Record 12 of Set 15 | touros
# Processing Record 13 of Set 15 | constitucion
# Processing Record 14 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 15 of Set 15 | karsava
# Processing Record 16 of Set 15 | severnoye
# Processing Record 17 of Set 15 | mackenzie
# Processing Record 18 of Set 15 | kismayo
# Processing Record 19 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 15 | muhlhausen
# Processing Record 21 of Set 15 | tessalit
# Processing Record 22 of Set 15 | inta
# Processing Record 23 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 24 of Set 15 | kloulklubed
# Processing Record 25 of Set 15 | mokhotlong
# Processing Record 26 of Set 15 | aktau
# Processing Record 27 of Set 15 | turan
# Processing Record 28 of Set 15 | montalban
# Processing Record 29 of Set 15 | elesbao veloso
# Processing Record 30 of Set 15 | makakilo city
# Processing Record 31 of Set 15 | cantagallo
# Processing Record 32 of Set 15 | gazanjyk
# Processing Record 33 of Set 15 | arys
# Processing Record 34 of Set 15 | broome
# Processing Record 35 of Set 15 | oakland
# Processing Record 36 of Set 15 | puebloviejo
# Processing Record 37 of Set 15 | karmana
# City not found. Skipping...
# Processing Record 38 of Set 15 | bitkine
# Processing Record 39 of Set 15 | hobyo
# Processing Record 40 of Set 15 | codrington
# Processing Record 41 of Set 15 | bolshaya vishera
# City not found. Skipping...
# Processing Record 42 of Set 15 | oktyabrskoye
# Processing Record 43 of Set 15 | tari
# Processing Record 44 of Set 15 | talas
# Processing Record 45 of Set 15 | tombouctou
# Processing Record 46 of Set 15 | berani
# Processing Record 47 of Set 15 | kracheh
# City not found. Skipping...
# Processing Record 48 of Set 15 | beckley
# Processing Record 49 of Set 15 | oxapampa
# Processing Record 50 of Set 15 | camana
# Processing Record 1 of Set 16 | prince rupert
# Processing Record 2 of Set 16 | kharan
# Processing Record 3 of Set 16 | elverum
# Processing Record 4 of Set 16 | sao felix do xingu
# Processing Record 5 of Set 16 | flin flon
# Processing Record 6 of Set 16 | itarantim
# Processing Record 7 of Set 16 | koslan
# Processing Record 8 of Set 16 | port macquarie
# Processing Record 9 of Set 16 | abu dhabi
# Processing Record 10 of Set 16 | santa isabel do rio negro
# Processing Record 11 of Set 16 | shache
# Processing Record 12 of Set 16 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 16 | deneysville
# Processing Record 14 of Set 16 | burias
# Processing Record 15 of Set 16 | roald
# Processing Record 16 of Set 16 | bandipur
# Processing Record 17 of Set 16 | saint-denis
# Processing Record 18 of Set 16 | tommot
# Processing Record 19 of Set 16 | cairns
# Processing Record 20 of Set 16 | south lake tahoe
# Processing Record 21 of Set 16 | fort-shevchenko
# Processing Record 22 of Set 16 | cabedelo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 710

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Tuatapere -46.13  167.68     48.99        87          16        8.99
# 1       Hobart -42.88  147.33     53.60        87          75        4.70
# 2         Miri   4.41  114.01     75.20        94          40        5.82
# 3      Agirish  61.92   63.02     26.19        97           0        8.25
# 4    Busselton -33.65  115.33     51.01        95          81        5.79
# 5     Cidreira -30.18  -50.21     65.98        62          25        9.40
# 6      Ushuaia -54.80  -68.30     57.20        58          75       11.41
# 7      Margate  51.38    1.39     63.00        94         100        7.00
# 8        Pevek  69.70  170.31     15.64        90         100       14.29
# 9  Ostrogozhsk  50.87   39.08     48.74        87          16        7.16
#
#   Country Current Description
# 0      NZ          few clouds
# 1      AU       broken clouds
# 2      MY       moderate rain
# 3      RU           clear sky
# 4      AU       broken clouds
# 5      BR    scattered clouds
# 6      AR          light rain
# 7      GB     overcast clouds
# 8      RU     overcast clouds
# 9      RU          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Tuatapere      NZ -46.13  167.68     48.99        87          16
# 1              Hobart      AU -42.88  147.33     53.60        87          75
# 2                Miri      MY   4.41  114.01     75.20        94          40
# 3             Agirish      RU  61.92   63.02     26.19        97           0
# 4           Busselton      AU -33.65  115.33     51.01        95          81
# ..                ...     ...    ...     ...       ...       ...         ...
# 705            Tommot      RU  58.96  126.29    -10.19        88          98
# 706            Cairns      AU -16.92  145.77     69.80        77          40
# 707  South Lake Tahoe      US  38.93 -119.98     64.99        23           1
# 708   Fort-Shevchenko      KZ  44.51   50.26     60.35        39           0
# 709          Cabedelo      BR  -6.98  -34.83     82.40        74          40
#
#      Wind Speed Current Description
# 0          8.99          few clouds
# 1          4.70       broken clouds
# 2          5.82       moderate rain
# 3          8.25           clear sky
# 4          5.79       broken clouds
# ..          ...                 ...
# 705        1.48     overcast clouds
# 706        5.82    scattered clouds
# 707        4.70           clear sky
# 708        4.63           clear sky
# 709       11.41    scattered clouds
#
# [710 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
